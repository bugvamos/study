# %%
from matplotlib import pyplot as plt
import random

# %%
x = range(2,26,2) # x轴的位置
y = [random.randint(15, 30) for i in x]

# %%
plt.figure(figsize=(20,8),dpi=80)

# %%
plt.xticks(x)
plt.xticks(range(1,25))
plt.yticks(y)
plt.yticks(range(min(y),max(y)+1))
# Out:
# ([<matplotlib.axis.YTick at 0x23770a46b70>,
#   <matplotlib.axis.YTick at 0x23770a45b80>,
#   <matplotlib.axis.YTick at 0x237713a1bb0>,
#   <matplotlib.axis.YTick at 0x237708e4aa0>,
#   <matplotlib.axis.YTick at 0x237708d9fa0>,
#   <matplotlib.axis.YTick at 0x237709df0b0>,
#   <matplotlib.axis.YTick at 0x23770922540>,
#   <matplotlib.axis.YTick at 0x23770922240>,
#   <matplotlib.axis.YTick at 0x237708d9b80>,
#   <matplotlib.axis.YTick at 0x23770921c70>,
#   <matplotlib.axis.YTick at 0x237708d4aa0>,
#   <matplotlib.axis.YTick at 0x237709b9d60>],
#  [Text(0, 15, '15'),
#   Text(0, 16, '16'),
#   Text(0, 17, '17'),
#   Text(0, 18, '18'),
#   Text(0, 19, '19'),
#   Text(0, 20, '20'),
#   Text(0, 21, '21'),
#   Text(0, 22, '22'),
#   Text(0, 23, '23'),
#   Text(0, 24, '24'),
#   Text(0, 25, '25'),
#   Text(0, 26, '26')])

# %%
x_ticks_label = ["{}:00".format(i) for i in x]
plt.xticks(x,x_ticks_label,rotation =45)
y_ticks_label = ["{}℃".format(i) for i in range(min(y),max(y)+1)]
plt.yticks(range(min(y),max(y)+1),y_ticks_label)
# Out:
# ([<matplotlib.axis.YTick at 0x237709ba330>,
#   <matplotlib.axis.YTick at 0x237709b8170>,
#   <matplotlib.axis.YTick at 0x2377144fd70>,
#   <matplotlib.axis.YTick at 0x2377144f2c0>,
#   <matplotlib.axis.YTick at 0x237714647a0>,
#   <matplotlib.axis.YTick at 0x23771465160>,
#   <matplotlib.axis.YTick at 0x23771465a90>,
#   <matplotlib.axis.YTick at 0x237714664e0>,
#   <matplotlib.axis.YTick at 0x2377144d2b0>,
#   <matplotlib.axis.YTick at 0x23771466cc0>,
#   <matplotlib.axis.YTick at 0x23771467650>,
#   <matplotlib.axis.YTick at 0x23771467fb0>],
#  [Text(0, 15, '15℃'),
#   Text(0, 16, '16℃'),
#   Text(0, 17, '17℃'),
#   Text(0, 18, '18℃'),
#   Text(0, 19, '19℃'),
#   Text(0, 20, '20℃'),
#   Text(0, 21, '21℃'),
#   Text(0, 22, '22℃'),
#   Text(0, 23, '23℃'),
#   Text(0, 24, '24℃'),
#   Text(0, 25, '25℃'),
#   Text(0, 26, '26℃')])

# %%
plt.plot(x,y)
plt.show()
